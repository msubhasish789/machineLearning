# %% [markdown]
# <a href="https://colab.research.google.com/github/msubhasish789/machineLearning/blob/main/Language_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data =  pd.read_csv("language_with_bengali.csv")

# %%
data.shape
# Out:
# (23003, 2)

# %%
data
# Out:
#                                                     Text  language
# 0      klement gottwaldi surnukeha palsameeriti ning ...  Estonian
# 1      sebes joseph pereira thomas  pÃ¥ eng the jesui...   Swedish
# 2      à¸–à¸™à¸™à¹€à¸ˆà¸£à¸´à¸à¸à¸£à¸¸à¸‡ à¸­à¸±à¸...      Thai
# 3      à®µà®¿à®šà®¾à®•à®ªà¯à®ªà®Ÿà¯à®Ÿà®¿à®©à®®à¯ ...     Tamil
# 4      de spons behoort tot het geslacht haliclona en...     Dutch
# ...                                                  ...       ...
# 22998                          যাই হোক সে আমার ঢের করেছে   Bengali
# 22999  তাহার কত দুঃখ বোধ হয় আমিও পৃথিবীর রং ফেরা দেখ...   Bengali
# 23000                                                NaN       NaN
# 23001                                                NaN       NaN
# 23002                                                NaN       NaN
#
# [23003 rows x 2 columns]

# %%
data.isnull().sum()
# Out:
# Text        3
# language    3
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# Text        0
# language    0
# dtype: int64

# %%
data["language"].value_counts()
# Out:
# language
# Estonian      1000
# Chinese       1000
# Arabic        1000
# English       1000
# Russian       1000
# Romanian      1000
# Persian       1000
# Pushto        1000
# Spanish       1000
# Hindi         1000
# Korean        1000
# French        1000
# Swedish       1000
# Portugese     1000
# Indonesian    1000
# Urdu          1000
# Latin         1000
# Turkish       1000
# Japanese      1000
# Dutch         1000
# Tamil         1000
# Thai          1000
# Bengali       1000
# Name: count, dtype: int64

# %%
x = np.array(data["Text"])
y = np.array(data["language"])

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
cv =  CountVectorizer()
X = cv.fit_transform(x)

# %%
X
# Out:
# <23000x136954 sparse matrix of type '<class 'numpy.int64'>'
# 	with 821718 stored elements in Compressed Sparse Row format>

# %%
X_train, X_test , y_train, y_test = train_test_split(X,y,test_size=0.3, random_state= 21)

# %%
model = MultinomialNB()

# %%
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
model.score(X_test, y_test)
# Out:
# 0.9818840579710145

# %%
inputText = input("Enter your text input : ")
data = cv.transform([inputText]).toarray()
output =  model.predict(data)
print("Your Entered Language is :", output)
# Out:
# Enter your text input : i am mantu
# Your Entered Language is : ['Romanian']
